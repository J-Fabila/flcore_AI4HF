# %%
from segmentation_model import UNet
from model_wrapper import ModelWrapper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_58344/3794946389.py in <module>
#       1 from segmentation_model import UNet
# ----> 2 from model_wrapper import ModelWrapper
#
# ~/work_dir/federado/Federado/flower_version/src/model_wrapper.py in <module>
#       9 from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
#      10
# ---> 11 from src.CIFAR_model import CIFAR_model
#      12 from src.segmentation_model import UNet
#      13 from src.resnet import ResNet152Segmentation
#
# ModuleNotFoundError: No module named 'src'
